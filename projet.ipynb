# %% [markdown]
# Python Data Science Project
# ===========================
#
# ### Lab based on data from The General Population and Housing Census of Morocco
# ### for Marrakech-Tensift-Haouz Region in 2004

# %%
# Import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Question 01: Reading Excel file
dfc = pd.read_excel('data_python/recensement_rgph004_region_mta.xlsx')

# %%
#Question 02: Showing Head and Tail of dataframe
dfc.head(10)
dfc.tail(10)
# Out:
#       ID        Nom_Commune Code_Commune Type_Commune  Surface_ha  Population  \
# 207  208            TIMLILT    161.09.15        Rural    24948.94        7186
# 208  209           TIZGUINE    041.05.19        Rural     5216.43        3886
# 209  210              TLAUH    427.09.19        Rural     9412.40        9901
# 210  211             TOUAMA    041.11.27        Rural    12115.52       11458
# 211  212    ZAOUIA ANNAHLIA    161.07.15        Rural    16721.78       15942
# 212  213  ZAOUIAT BEN HMIDA    211.03.51        Rural     6361.56        6395
# 213  214            ZEMRANE    191.07.31        Rural    19353.68       15996
# 214  215    ZEMRANE CHARQIA    191.07.33        Rural    21809.44       27408
# 215  216            ZERKTEN    041.11.29        Rural    39117.49       19124
# 216  217              ZNADA    191.03.41        Rural     4625.65        8830
#
#      Pop_inf6_pc  Pop_615_pc  Pop_1560_pc  Pop_sup60_pc  Celebataire_pc  \
# 207         15.8        24.2         51.2           8.8            36.1
# 208         11.3        19.7         55.2          13.8            26.4
# 209         13.2        21.2         57.7           7.9            35.0
# 210         11.5        19.8         58.7          10.0            37.4
# 211         15.1        23.7         54.1           7.1            34.4
# 212         13.3        20.2         55.9          10.6            35.1
# 213         12.7        21.5         57.3           8.4            35.3
# 214         11.4        21.0         59.0           8.5            36.9
# 215         13.6        24.1         54.4           7.9            33.8
# 216         13.5        22.9         57.5           6.1            32.5
#
#      Marie_pc  Mrge_Autre_pc  Age_Moyen_1marriage  Taux_Analphabetisme  \
# 207      58.4            5.5                 26.9                 77.6
# 208      63.8            9.7                 25.5                 60.9
# 209      59.2            5.8                 27.0                 58.9
# 210      55.5            7.1                 28.4                 63.1
# 211      60.4            5.1                 26.2                 71.4
# 212      57.5            7.4                 26.8                 67.2
# 213      59.0            5.8                 26.6                 61.7
# 214      56.1            7.0                 27.6                 55.4
# 215      59.4            6.8                 25.4                 72.9
# 216      61.3            6.2                 25.6                 57.5
#
#      Taux_activite
# 207           27.9
# 208           29.6
# 209           34.4
# 210           36.7
# 211           35.2
# 212           32.5
# 213           33.0
# 214           34.5
# 215           36.3
# 216           31.9

# %%
#Question 03: Calculating min, max, mean, median, sum and standard deviation
# of Population and Surface_ha
#dfc['Population'].describe()
print('Min of Population: ', dfc['Population'].min())
print('Max of Population: ', dfc['Population'].max())
print('Mean of Population: ', dfc['Population'].mean().round(2))
print('Median of Population: ', dfc['Population'].median().round(2))
print('Sum of Population: ', dfc['Population'].sum())
print('Std of Population: ', dfc['Population'].std().round(2))
print('='*40)
print('Min of Surface en H: ', dfc['Surface_ha'].min())
print('Max of Surface en H: ', dfc['Surface_ha'].max())
print('Mean of Surface en H: ', dfc['Surface_ha'].mean().round(2))
print('Median of Surface en H: ', dfc['Surface_ha'].median().round(2))
print('Sum of Surface en H: ', dfc['Surface_ha'].sum().round(2))
print('Std of Surface en H: ', dfc['Surface_ha'].std().round(2))
# Out:
# Min of Population:  2497
# Max of Population:  280275
# Mean of Population:  14231.97
# Median of Population:  8382.0
# Sum of Population:  3088338
# Std of Population:  26408.71
# ========================================
# Min of Surface en H:  608.97
# Max of Surface en H:  73905.83
# Mean of Surface en H:  14780.49
# Median of Surface en H:  11335.56
# Sum of Surface en H:  3207367.24
# Std of Surface en H:  11086.24

# %%
#Question 04: Deleting ID Column
dfc.drop('ID', axis=1, inplace=True)

# %%
#Question 05: Number of Unique values
print('Number of unique values: ', dfc['Nom_Commune'].nunique())

#Values frequency
commune = dfc['Nom_Commune']
print('Duplicated values frequency: ', commune[commune.duplicated()].value_counts().to_dict())
# Out:
# Number of unique values:  215
# Duplicated values frequency:  {'SIDI GHANEM': 2}

# %%
#Question 06: Commune with high activity rate and low activity rate
dfc.sort_values('Taux_activite', ascending=False, inplace=True)
print('Commune with high activity rate: ', dfc[['Nom_Commune', 'Taux_activite']].iloc[0].to_list())
print('Commune with low activity rate: ', dfc[['Nom_Commune', 'Taux_activite']].iloc[-1].to_list())
# Out:
# Commune with high activity rate:  ["SIDI H'MAD  OU M'BAREK", 51.2]
# Commune with low activity rate:  ['LALLA AAZIZA', 24.5]

# %%
#Question 07: Commune with Population greater than 10000 and Illiteracy rate greater than 40%
dfc[(dfc['Population']>10000) & (dfc['Taux_Analphabetisme']>40)]
# Out:
#         Nom_Commune Code_Commune Type_Commune  Surface_ha  Population  \
# 164     SIDI GHANEM    161.05.15        Rural    31154.05       12159
# 30             ASNI    041.07.03        Rural    26106.79       18617
# 204     TIGHEDOUINE    041.11.25        Rural    36228.71       22347
# 27         ANNAKHIL    351.01.03       Urbain     6605.11       54111
# 171  SIDI LAAROUSSI    211.03.43        Rural    24642.74       13203
# ..              ...          ...          ...         ...         ...
# 114   NZALAT LAADAM    427.09.09        Rural    48017.06       11097
# 56           FRAITA    191.05.09        Rural     8214.99       10555
# 117         OUARGUI    191.05.21        Rural     5949.79       10113
# 85       LAATTAOUIA    191.01.05       Urbain     2078.10       20237
# 47         DOUIRANE    161.07.05        Rural    16677.41       14180
#
#      Pop_inf6_pc  Pop_615_pc  Pop_1560_pc  Pop_sup60_pc  Celebataire_pc  \
# 164         13.5        24.6         53.2           8.7            33.2
# 30          12.9        24.0         56.1           7.1            35.0
# 204         14.3        25.0         53.6           7.1            34.6
# 27          12.2        18.5         63.0           6.3            38.0
# 171         14.8        24.4         51.2           9.6            34.0
# ..           ...         ...          ...           ...             ...
# 114         14.5        23.4         55.6           6.5            33.4
# 56          12.8        23.9         55.3           8.0            32.1
# 117         11.5        22.1         58.4           8.0            39.4
# 85          13.3        23.7         57.4           5.5            35.5
# 47          14.3        25.7         52.1           7.9            33.2
#
#      Marie_pc  Mrge_Autre_pc  Age_Moyen_1marriage  Taux_Analphabetisme  \
# 164      60.5            6.3                 26.9                 75.7
# 30       58.9            6.1                 26.3                 59.2
# 204      59.1            6.3                 25.7                 75.8
# 27       55.2            6.8                 27.5                 47.1
# 171      59.1            7.0                 27.9                 53.0
# ..        ...            ...                  ...                  ...
# 114      61.9            4.7                 25.5                 51.6
# 56       60.6            7.3                 25.7                 59.2
# 117      54.1            6.5                 28.2                 52.6
# 85       57.6            6.8                 26.6                 40.3
# 47       59.6            7.2                 26.3                 65.8
#
#      Taux_activite
# 164           48.6
# 30            43.9
# 204           41.2
# 27            40.0
# 171           39.9
# ..             ...
# 114           29.2
# 56            29.1
# 117           29.0
# 85            28.9
# 47            28.8
#
# [70 rows x 15 columns]

# %%
#Question 08: Commune name starts or ends with an "A"
dfc[(dfc['Nom_Commune'].str.startswith('A')) | (dfc['Nom_Commune'].str.endswith('A'))]
# Out:
#             Nom_Commune Code_Commune Type_Commune  Surface_ha  Population  \
# 2               ADASSIL    161.07.01        Rural    14560.61        7212
# 30                 ASNI    041.07.03        Rural    26106.79       18617
# 103             MESKALA    211.03.17        Rural     8462.47        4220
# 7                AGUERD    211.05.05        Rural     8897.58        4917
# 99     MARRAKECH-MÉDINA    351.01.07       Urbain      608.97      166711
# ..                  ...          ...          ...         ...         ...
# 14   AIT HADDOU YOUSSEF    161.05.05        Rural    15838.45        5537
# 6                 AGLIF    211.05.03        Rural    19199.77        8934
# 50            EL AAMRIA    191.03.05        Rural     4947.09        8382
# 34               AZGOUR    041.05.07        Rural    17135.75        6314
# 90         LALLA AAZIZA    161.05.09        Rural    27603.44        7781
#
#      Pop_inf6_pc  Pop_615_pc  Pop_1560_pc  Pop_sup60_pc  Celebataire_pc  \
# 2           15.4        26.9         49.8           7.9            27.4
# 30          12.9        24.0         56.1           7.1            35.0
# 103         11.9        20.9         56.0          11.1            33.6
# 7           12.7        20.2         55.2          11.9            32.3
# 99           9.0        14.9         65.2          10.9            42.6
# ..           ...         ...          ...           ...             ...
# 14          19.1        25.6         48.6           6.8            27.7
# 6           15.7        25.3         49.0           9.9            30.4
# 50          14.9        21.6         55.3           8.2            28.9
# 34          13.0        25.1         51.9          10.0            25.8
# 90          17.9        26.1         48.3           7.7            27.6
#
#      Marie_pc  Mrge_Autre_pc  Age_Moyen_1marriage  Taux_Analphabetisme  \
# 2        65.5            7.1                 24.7                 78.2
# 30       58.9            6.1                 26.3                 59.2
# 103      58.5            7.9                 27.3                 70.6
# 7        60.7            7.0                 26.9                 72.2
# 99       45.3           12.1                 30.4                 34.7
# ..        ...            ...                  ...                  ...
# 14       65.9            6.4                 23.6                 80.0
# 6        62.4            7.1                 25.8                 77.4
# 50       63.3            7.8                 24.5                 63.3
# 34       66.2            8.0                 24.4                 69.1
# 90       65.7            6.7                 24.1                 78.1
#
#      Taux_activite
# 2             48.0
# 30            43.9
# 103           43.7
# 7             42.1
# 99            41.0
# ..             ...
# 14            28.0
# 6             28.0
# 50            27.5
# 34            25.7
# 90            24.5
#
# [90 rows x 15 columns]

# %%
#Question 08: Bar Chart of population by Commune
dfc[['Nom_Commune', 'Population']].head(10).plot.bar(x='Nom_Commune').set(
    title='Population By Commune',
    xlabel='Commune',
    ylabel='Population'
)
# Out:
# [Text(0, 0.5, 'Population'),
#  Text(0.5, 0, 'Commune'),
#  Text(0.5, 1.0, 'Population By Commune')]

# %%
#Question 10: Stacked Bar Chart of Activity rate by Illiteracy rate
dfc[['Taux_Analphabetisme', 'Taux_activite', 'Nom_Commune']].plot.scatter(x='Taux_Analphabetisme', y='Taux_activite').set(
    title='Illiteracy rate by Activity rate',
    xlabel='Illiteracy rate',
    ylabel='Activity rate'
)
# Out:
# [Text(0, 0.5, 'Activity rate'),
#  Text(0.5, 0, 'Illiteracy rate'),
#  Text(0.5, 1.0, 'Illiteracy rate by Activity rate')]

# %%
#Question 11: Adding "densite_pop" popultaion/area
dfc.insert(5, "Densite_Pop", round(dfc["Population"]/dfc["Surface_ha"]*100,2))

# %%
dfc.describe()
# Out:
#          Surface_ha     Population   Densite_Pop  Pop_inf6_pc  Pop_615_pc  \
# count    217.000000     217.000000    217.000000   217.000000  217.000000
# mean   14780.494194   14231.972350    361.792350    13.391244   22.190783
# std    11086.244348   26408.711418   2028.160908     1.641862    2.154304
# min      608.970000    2497.000000     19.000000     8.400000   14.100000
# 25%     7429.000000    6313.000000     45.070000    12.500000   20.800000
# 50%    11335.560000    8382.000000     70.240000    13.200000   22.200000
# 75%    19576.500000   12196.000000    128.480000    14.300000   23.800000
# max    73905.830000  280275.000000  27375.900000    19.100000   26.900000
#
#        Pop_1560_pc  Pop_sup60_pc  Celebataire_pc    Marie_pc  Mrge_Autre_pc  \
# count   217.000000    217.000000      217.000000  217.000000     217.000000
# mean     55.545161      8.876037       33.885253   59.017512       7.098157
# std       3.441830      1.670212        3.327212    3.494714       1.099535
# min      47.300000      5.300000       22.100000   43.900000       4.700000
# 25%      53.600000      7.800000       32.200000   56.800000       6.400000
# 50%      55.500000      8.800000       34.000000   59.000000       7.000000
# 75%      57.500000      9.900000       36.000000   61.100000       7.600000
# max      65.500000     13.900000       43.700000   71.300000      12.400000
#
#        Age_Moyen_1marriage  Taux_Analphabetisme  Taux_activite
# count           217.000000           217.000000     217.000000
# mean             26.524424            63.933180      34.701382
# std               1.332431            11.788071       4.420056
# min              22.000000            22.500000      24.500000
# 25%              25.600000            57.800000      31.500000
# 50%              26.400000            65.800000      34.300000
# 75%              27.400000            72.100000      36.800000
# max              31.100000            90.100000      51.200000

# %%
#Question 12: Retrieving State code from Municipality code
def codeProvince(codeCommune):
    return codeCommune[:3] if len(codeCommune) > 3 else None

# %%
#Question 12: Adding State code column
dfc.insert(3, 'Code_Province', dfc['Code_Commune'].apply(codeProvince))

# %%
#Question 13: Retrieving State name by State code
def nomProvince(codeProvince):
    try:
        df = pd.read_csv('data_python/code_nom_province.csv', dtype=str)
        df.set_index('Code_Province', inplace=True)
        return df.loc[codeProvince][0]
    except:
        return None

# %%
#Question 13: Adding State name column
dfc.insert(4, 'Nom_Province', dfc['Code_Province'].apply(nomProvince))

# %%
#Question 14: Setting State and Municipality as indexes
dfc.set_index(['Code_Province', 'Code_Commune'], inplace=True)
dfc.sort_index(inplace=True)

# %%
#Question 15: Exporting DataFrame
dfc.to_excel('data_python/dfc_Abidar_El_Mehdi_Absidi_Mehdi.xlsx')

# %%
dfc.head()
# Out:
#                                Nom_Commune Type_Commune Nom_Province  \
# Code_Province Code_Commune
# 041           041.01.01          AIT OURIR       Urbain     AL HAOUZ
#               041.01.03            AMIZMIZ        Rural     AL HAOUZ
#               041.01.09         TAHANNAOUT        Rural     AL HAOUZ
#               041.03.05          AIT FASKA        Rural     AL HAOUZ
#               041.03.09     AIT SIDI DAOUD        Rural     AL HAOUZ
#
#                             Surface_ha  Population  Densite_Pop  Pop_inf6_pc  \
# Code_Province Code_Commune
# 041           041.01.01        1077.92       19864      1842.81         11.5
#               041.01.03        4540.87       13650       300.60         10.9
#               041.01.09       26702.52       29552       110.67         12.2
#               041.03.05       11046.10       19228       174.07         10.9
#               041.03.09       11424.64       19275       168.71         11.8
#
#                             Pop_615_pc  Pop_1560_pc  Pop_sup60_pc  \
# Code_Province Code_Commune
# 041           041.01.01           20.2         61.4           6.9
#               041.01.03           19.0         60.6           9.5
#               041.01.09           21.8         58.4           7.5
#               041.03.05           20.1         60.3           8.6
#               041.03.09           20.0         59.1           9.1
#
#                             Celebataire_pc  Marie_pc  Mrge_Autre_pc  \
# Code_Province Code_Commune
# 041           041.01.01               38.5      54.6            7.0
#               041.01.03               34.3      56.7            8.9
#               041.01.09               38.0      55.9            6.1
#               041.03.05               39.3      53.4            7.3
#               041.03.09               36.5      56.6            6.9
#
#                             Age_Moyen_1marriage  Taux_Analphabetisme  \
# Code_Province Code_Commune
# 041           041.01.01                    28.4                 37.7
#               041.01.03                    28.1                 39.7
#               041.01.09                    27.9                 52.5
#               041.03.05                    28.3                 58.7
#               041.03.09                    28.0                 62.7
#
#                             Taux_activite
# Code_Province Code_Commune
# 041           041.01.01              29.6
#               041.01.03              31.5
#               041.01.09              34.2
#               041.03.05              34.0
#               041.03.09              34.9

# %%
#Question 16: Calculating number of Commune by type
dfc.groupby(['Code_Province', 'Nom_Province'])['Type_Commune'].value_counts()
# Out:
# Code_Province  Nom_Province    Type_Commune
# 041            AL HAOUZ        Rural           38
#                                Urbain           1
# 161            CHICHAOUA       Rural           35
#                                Urbain           2
# 191            KELAA SERAGHNA  Rural           38
#                                Urbain           4
# 211            ESSAOUIRA       Rural           51
#                                Urbain           5
# 351            MARRAKECH       Rural           13
#                                Urbain           6
# Name: Type_Commune, dtype: int64

# %%
#Question 17: Calculating activity rate
dfc.groupby(['Code_Province', 'Nom_Province'])['Taux_activite'].mean().round(2)
# Out:
# Code_Province  Nom_Province
# 041            AL HAOUZ          35.52
# 161            CHICHAOUA         33.98
# 191            KELAA SERAGHNA    32.57
# 211            ESSAOUIRA         35.78
# 351            MARRAKECH         36.44
# Name: Taux_activite, dtype: float64

# %%
#Question 18: Generating dpf Dataframe
dfc['Population_Active'] = dfc.apply(lambda x: int(x['Taux_activite']*x['Population']/100), axis=1)
dfp = dfc.groupby(['Nom_Province', 'Code_Province']).agg({
    'Surface_ha':'sum',
    'Population':'sum',
    'Population_Active':'sum'
})
dfp
# Out:
#                               Surface_ha  Population  Population_Active
# Nom_Province   Code_Province
# AL HAOUZ       041             606789.04      483741             173563
# CHICHAOUA      161             752211.29      356750             122066
# ESSAOUIRA      211             649917.88      446959             161431
# KELAA SERAGHNA 191             393128.52      454851             147353
# MARRAKECH      351             258953.71     1063415             400995

# %%
#Question 19: Generating dpf Dataframe
dfp['Taux_activite'] = round(dfp['Population_Active'] / dfp['Population'] * 100, 2)
dfp['Taux_analphabetisme'] = round(dfc.groupby(['Nom_Province', 'Code_Province'])['Taux_Analphabetisme'].mean(), 2)
dfp
# Out:
#                               Surface_ha  Population  Population_Active  \
# Nom_Province   Code_Province
# AL HAOUZ       041             606789.04      483741             173563
# CHICHAOUA      161             752211.29      356750             122066
# ESSAOUIRA      211             649917.88      446959             161431
# KELAA SERAGHNA 191             393128.52      454851             147353
# MARRAKECH      351             258953.71     1063415             400995
#
#                               Taux_activite  Taux_analphabetisme
# Nom_Province   Code_Province
# AL HAOUZ       041                    35.88                64.10
# CHICHAOUA      161                    34.22                70.06
# ESSAOUIRA      211                    36.12                68.15
# KELAA SERAGHNA 191                    32.40                58.86
# MARRAKECH      351                    37.71                50.12

# %%
#Question 20: Adding Proportions by age
dfp['Pop_inf6_pc'] = round(dfc.groupby(['Nom_Province', 'Code_Province'])['Pop_inf6_pc'].mean(), 2)
dfp['Pop_615_pc'] = round(dfc.groupby(['Nom_Province', 'Code_Province'])['Pop_615_pc'].mean(), 2)
dfp['Pop_1560_pc'] = round(dfc.groupby(['Nom_Province', 'Code_Province'])['Pop_1560_pc'].mean(), 2)
dfp['Pop_sup60_pc'] = round(dfc.groupby(['Nom_Province', 'Code_Province'])['Pop_sup60_pc'].mean(), 2)
dfp
# Out:
#                               Surface_ha  Population  Population_Active  \
# Nom_Province   Code_Province
# AL HAOUZ       041             606789.04      483741             173563
# CHICHAOUA      161             752211.29      356750             122066
# ESSAOUIRA      211             649917.88      446959             161431
# KELAA SERAGHNA 191             393128.52      454851             147353
# MARRAKECH      351             258953.71     1063415             400995
#
#                               Taux_activite  Taux_analphabetisme  Pop_inf6_pc  \
# Nom_Province   Code_Province
# AL HAOUZ       041                    35.88                64.10        13.07
# CHICHAOUA      161                    34.22                70.06        14.35
# ESSAOUIRA      211                    36.12                68.15        13.63
# KELAA SERAGHNA 191                    32.40                58.86        13.04
# MARRAKECH      351                    37.71                50.12        12.38
#
#                               Pop_615_pc  Pop_1560_pc  Pop_sup60_pc
# Nom_Province   Code_Province
# AL HAOUZ       041                 22.77        55.34          8.81
# CHICHAOUA      161                 23.63        53.22          8.81
# ESSAOUIRA      211                 21.74        54.22         10.42
# KELAA SERAGHNA 191                 22.44        56.70          7.83
# MARRAKECH      351                 19.15        60.65          7.83

# %%
#Question 21: Exporting DataFrame
dfc.to_excel('data_python/dfp_Abidar_El_Mehdi_Absidi_Mehdi.xlsx')

# %%
#Question 22: Graph of Population and Active Popultaion by State
dfp[['Population_Active', 'Population']].sort_values(['Population_Active', 'Population']).plot.bar(stacked=True).set(
    title='Population and Active Popultaion by State',
    xlabel='States',
    ylabel='Population/Active'
)
# Out:
# [Text(0, 0.5, 'Population/Active'),
#  Text(0.5, 0, 'States'),
#  Text(0.5, 1.0, 'Population and Active Popultaion by State')]

# %%
#Question 23: Graph of Activity and Illiteracy rate by State
dfp[['Taux_activite', 'Taux_analphabetisme']].sort_values(['Taux_activite', 'Taux_analphabetisme']).plot.bar().set(
    title='Activity and Illiteracy rate by State',
    xlabel='States',
    ylabel='Activity and Illiteracy rate'
)
# Out:
# [Text(0, 0.5, 'Activity and Illiteracy rate'),
#  Text(0.5, 0, 'States'),
#  Text(0.5, 1.0, 'Activity and Illiteracy rate by State')]

# %%
#Question 24: Graph of Age band by State
dfp[['Pop_inf6_pc','Pop_615_pc','Pop_1560_pc','Pop_sup60_pc']].plot.bar().set(
    title='Age band by State',
    xlabel='States',
    ylabel='Age band'
)
# Out:
# [Text(0, 0.5, 'Age band'),
#  Text(0.5, 0, 'States'),
#  Text(0.5, 1.0, 'Age band by State')]

# %%
#Question 24: Function to retrieve data from rgph site by state code
import requests
def get_commune_data_url(code_commune):
    # Themes :
    # 2 for demographic theme (Population & First mariage age)
    # 4 for education theme theme (Illiteracy rate)
    # 6 for Activity/Jobs theme (Activity rate)
    HEADERS = {
        'Referer': 'http://rgphentableaux.hcp.ma/Default1/'
    }
    THEMES = [2, 4, 6]

    data = {'Code_Commune': code_commune}

    for theme in THEMES:
        url = f'http://rgphentableaux.hcp.ma/Default1/getDATA/?type=Commune&CGEO={code_commune}.&them={theme}'
        result = requests.get(url, headers=HEADERS).json()
        for line in result:
            indicator = line.get('INDICATEUR')

            if indicator == 'IEE_Population municipale':
                data['Population_2014'] = int(line['DATA2014'])

            if indicator == 'IUE_Âge moyen au premier mariage' and line['DATA2014'] != '-':
                data['Age_moyen_mariage_2014'] = line['DATA2014']
            elif indicator == 'IRE_Âge moyen au premier mariage':
                data['Age_moyen_mariage_2014'] = line['DATA2014']

            if indicator == "IEE_Taux d'analphabétisme":
                data['Taux_analphabetisme_2014'] = line['DATA2014']

            if indicator == "IEE_Taux net d'activité":
                data['Taux_activite_2014'] = line['DATA2014']

    return data

# %%
#Question 24: Retrieving data from rgph site by state code
dfc.reset_index(inplace=True)
dfc_from_url = pd.DataFrame([get_commune_data_url(code_commune) for code_commune in dfc['Code_Commune']])
dfc2 = pd.merge(dfc.drop_duplicates('Code_Commune'), dfc_from_url.drop_duplicates('Code_Commune'), on='Code_Commune')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386         else:
# --> 387             conn.request(method, url, **httplib_request_kw)
#     388
#
# c:\users\mir\appdata\local\programs\python\python37\Lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# c:\users\mir\appdata\local\programs\python\python37\Lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# c:\users\mir\appdata\local\programs\python\python37\Lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# c:\users\mir\appdata\local\programs\python\python37\Lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# c:\users\mir\appdata\local\programs\python\python37\Lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\connection.py in connect(self)
#     183     def connect(self):
# --> 184         conn = self._new_conn()
#     185         self._prepare_conn(conn)
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e
#     170             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000026D661BD808>: Failed to establish a new connection: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Documents\Dev\ehtp\venv\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPConnectionPool(host='rgphentableaux.hcp.ma', port=80): Max retries exceeded with url: /Default1/getDATA/?type=Commune&CGEO=191.07.31.&them=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000026D661BD808>: Failed to establish a new connection: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-31-5757c9cf5b84> in <module>
#       1 #Question 24: Retrieving data from rgph site by state code
#       2 dfc.reset_index(inplace=True)
# ----> 3 dfc_from_url = pd.DataFrame([get_commune_data_url(code_commune) for code_commune in dfc['Code_Commune']])
#       4 # dfc2 = pd.merge(dfc, dfc_from_url, on='New_Code_Commune')
#       5 dfc_from_url.head()
#
# <ipython-input-31-5757c9cf5b84> in <listcomp>(.0)
#       1 #Question 24: Retrieving data from rgph site by state code
#       2 dfc.reset_index(inplace=True)
# ----> 3 dfc_from_url = pd.DataFrame([get_commune_data_url(code_commune) for code_commune in dfc['Code_Commune']])
#       4 # dfc2 = pd.merge(dfc, dfc_from_url, on='New_Code_Commune')
#       5 dfc_from_url.head()
#
# <ipython-input-30-f4d3419eb4e1> in get_commune_data_url(code_commune)
#      15     for theme in THEMES:
#      16         url = f'http://rgphentableaux.hcp.ma/Default1/getDATA/?type=Commune&CGEO={code_commune}.&them={theme}'
# ---> 17         result = requests.get(url, headers=HEADERS).json()
#      18         for line in result:
#      19             indicator = line.get('INDICATEUR')
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Documents\Dev\ehtp\venv\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='rgphentableaux.hcp.ma', port=80): Max retries exceeded with url: /Default1/getDATA/?type=Commune&CGEO=191.07.31.&them=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000026D661BD808>: Failed to establish a new connection: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu'))

# %%
#Question 26: Calculating Population growth rate by Commune
dfc2['Taux_Acroissement'] = ((dfc2['Population_2014'] - dfc2['Population']) / dfc2['Population']).round(2)
dfc2['Taux_Acroissement'].head()
# Out:
# 0    0.97
# 1    0.05
# 2   -0.61
# 3    0.36
# 4   -0.02
# Name: Taux_Acroissement, dtype: float64

# %%
#Question 27: Calculating Population growth rate by State
dfc2.groupby(['Code_Province', 'Nom_Province'])['Taux_Acroissement'].mean().round(2)
# Out:
# Code_Province  Nom_Province
# 041            AL HAOUZ          0.11
# 161            CHICHAOUA         0.05
# 191            KELAA SERAGHNA    0.12
# 211            ESSAOUIRA        -0.03
# 351            MARRAKECH         0.40
# Name: Taux_Acroissement, dtype: float64

# %%
#Question 28: Variation of population by state between 2004 and 2014
dfc_for_graph = dfc2.groupby('Nom_Province')['Population','Population_2014'].sum()
dfc_for_graph.plot(y=['Population','Population_2014']).set(
    title='Population 2004|Population 2014',
    xlabel='State',
    ylabel='Population 2004|Population 2014'
)
# Out:
# [Text(0, 0.5, 'Population 2004|Population 2014'),
#  Text(0.5, 0, 'State'),
#  Text(0.5, 1.0, 'Population 2004|Population 2014')]

# %%
#Question 28: Variation of population by state between 2004 and 2014
dfc.to_excel('data_python/dfc2_Abidar_El_Mehdi.xlsx')
